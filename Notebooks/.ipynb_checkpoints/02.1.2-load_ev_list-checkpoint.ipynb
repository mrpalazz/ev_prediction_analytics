# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from os import listdir
from os.path import isfile, join

import os 
from pathlib import Path

# %% [markdown]
# ### Import the data from the FEV vehicle catalog

# %%
#wd = Path(os.getcwd())
wd = Path.cwd()
parent_wd = wd.parent.absolute()
file_name = "FEV-data-Excel.xlsx"
file_path = f"{parent_wd}\\Data\\{file_name}"
print(file_path)
print(parent_wd)
# Out:
# C:\Users\mrpal\OneDrive\Springboard\ev_prediction_analytics\Data\FEV-data-Excel.xlsx
# C:\Users\mrpal\OneDrive\Springboard\ev_prediction_analytics

# %%
ev_vehicles = pd.DataFrame(pd.read_excel(file_path, header=0))

# %%
ev_vehicles.head()
# Out:
#                       Car full name  Make                        Model  \
# 0            Audi e-tron 55 quattro  Audi            e-tron 55 quattro
# 1            Audi e-tron 50 quattro  Audi            e-tron 50 quattro
# 2             Audi e-tron S quattro  Audi             e-tron S quattro
# 3  Audi e-tron Sportback 50 quattro  Audi  e-tron Sportback 50 quattro
# 4  Audi e-tron Sportback 55 quattro  Audi  e-tron Sportback 55 quattro
#
#    Minimal price (gross) [PLN]  Engine power [KM]  Maximum torque [Nm]  \
# 0                       345700                360                  664
# 1                       308400                313                  540
# 2                       414900                503                  973
# 3                       319700                313                  540
# 4                       357000                360                  664
#
#         Type of brakes Drive type  Battery capacity [kWh]  Range (WLTP) [km]  \
# ...

# %% [markdown]
# ### Save the EV data to a Pickle file so it can be loaded into future processes

# %%
ev_vehicles.to_pickle("ev_vehicle_data_raw.pkl")

# %%
raw_output = pd.read_pickle("ev_vehicle_data_raw.pkl")

# %%
raw_output.head()
# Out:
#                       Car full name  Make                        Model  \
# 0            Audi e-tron 55 quattro  Audi            e-tron 55 quattro
# 1            Audi e-tron 50 quattro  Audi            e-tron 50 quattro
# 2             Audi e-tron S quattro  Audi             e-tron S quattro
# 3  Audi e-tron Sportback 50 quattro  Audi  e-tron Sportback 50 quattro
# 4  Audi e-tron Sportback 55 quattro  Audi  e-tron Sportback 55 quattro
#
#    Minimal price (gross) [PLN]  Engine power [KM]  Maximum torque [Nm]  \
# 0                       345700                360                  664
# 1                       308400                313                  540
# 2                       414900                503                  973
# 3                       319700                313                  540
# 4                       357000                360                  664
#
#         Type of brakes Drive type  Battery capacity [kWh]  Range (WLTP) [km]  \
# ...
