# %% [markdown]
# # Table of Contents
#
# 1. [Load Packages and Data](#paragraph1)
# 2. [Raw Data Analysis](#paragraph2)
#     1. [EV Survey Data](#subparagraph1)

# %% [markdown]
# ## Load Packages and Raw Data<a name="paragraph1"></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas_profiling import ProfileReport

from os import listdir
from os.path import isfile, join

import os 
from pathlib import Path

# %%
#collect info about current working directory and the location of the raw data pickle files

wd = Path(os.getcwd())
parent_dir = wd.parent.absolute()

# %%
#Data for the EV Vehicle list and attributes
filename = "ev_vehicle_data_raw.pkl"
filepath = f"{wd}\\{filename}"

ev_vehicle_data_raw = pd.read_pickle(filepath)
ev_vehicle_data_raw.head()
# Out:
#                       Car full name  Make                        Model  \
# 0            Audi e-tron 55 quattro  Audi            e-tron 55 quattro
# 1            Audi e-tron 50 quattro  Audi            e-tron 50 quattro
# 2             Audi e-tron S quattro  Audi             e-tron S quattro
# 3  Audi e-tron Sportback 50 quattro  Audi  e-tron Sportback 50 quattro
# 4  Audi e-tron Sportback 55 quattro  Audi  e-tron Sportback 55 quattro
#
#    Minimal price (gross) [PLN]  Engine power [KM]  Maximum torque [Nm]  \
# 0                       345700                360                  664
# 1                       308400                313                  540
# 2                       414900                503                  973
# 3                       319700                313                  540
# 4                       357000                360                  664
#
#         Type of brakes Drive type  Battery capacity [kWh]  Range (WLTP) [km]  \
# 0  disc (front + rear)        4WD                    95.0                438
# 1  disc (front + rear)        4WD                    71.0                340
# 2  disc (front + rear)        4WD                    95.0                364
# 3  disc (front + rear)        4WD                    71.0                346
# 4  disc (front + rear)        4WD                    95.0                447
#
#    ...  Permissable gross weight [kg]  Maximum load capacity [kg]  \
# 0  ...                         3130.0                       640.0
# 1  ...                         3040.0                       670.0
# 2  ...                         3130.0                       565.0
# 3  ...                         3040.0                       640.0
# 4  ...                         3130.0                       670.0
#
#    Number of seats  Number of doors  Tire size [in]  Maximum speed [kph]  \
# 0                5                5              19                  200
# 1                5                5              19                  190
# 2                5                5              20                  210
# 3                5                5              19                  190
# 4                5                5              19                  200
#
#    Boot capacity (VDA) [l]  Acceleration 0-100 kph [s]  \
# 0                    660.0                         5.7
# 1                    660.0                         6.8
# 2                    660.0                         4.5
# 3                    615.0                         6.8
# 4                    615.0                         5.7
#
#    Maximum DC charging power [kW]  mean - Energy consumption [kWh/100 km]
# 0                             150                                   24.45
# 1                             150                                   23.80
# 2                             150                                   27.55
# 3                             150                                   23.30
# 4                             150                                   23.85
#
# [5 rows x 25 columns]

# %%
#Data for the EV survey
filename = "ev_survey_output_raw.pkl"
filepath = f"{wd}\\{filename}"
ev_survey_output_raw = pd.read_pickle(filepath)
ev_survey_output_raw.head()
# Out:
#    response_id  year_submitted_survey_2  months_owned  \
# 0          1.0                   2019.0          24.0
# 1          2.0                   2019.0          20.0
# 2          3.0                   2019.0          23.0
# 3          4.0                   2019.0          45.0
# 4          5.0                   2019.0          19.0
#
#                  year_make_model  electric_range ev_type discontinuance  \
# 0                    2016 BMW i3            81.0    PHEV      Continued
# 1  2018 Tesla Model 3 Long Range           310.0     BEV       Original
# 2            2017 Chevrolet Volt            53.0    PHEV       Original
# 3             2016 Tesla Model S           271.0     BEV       Original
# 4               2019 Nissan Leaf            84.0     BEV       Original
#
#    surveyed_age surveyed_gender  dist_1  ...  range_satisfaction  \
# 0          25.0            Male   13.92  ...                 5.0
# 1          35.0            Male   10.25  ...                 5.0
# 2          45.0            Male     NaN  ...                 2.0
# 3          45.0            Male    8.68  ...                 4.0
# 4          65.0            Male     NaN  ...                 4.0
#
#    charge_access_satisfaction  adas_satisfaction        household_income  \
# 0                         5.0                5.0    $150,000 to $199,999
# 1                         5.0                5.0                     NaN
# 2                         3.0                2.0    $200,000 to $249,999
# 3                         4.0                4.0  I prefer not to answer
# 4                         5.0                5.0    $200,000 to $249,999
#
#    home_charge_type  work_charge_type  highest_charge_used  \
# 0       No Charging       No charging              Level 2
# 1           Level 2           DC Fast          No charging
# 2       No Charging           Level 2          No charging
# 3           Level 2       No charging          No charging
# 4           Level 2           Level 2          No charging
#
#    backup_vehicle_mpg  finance_type  last_page
# 0                25.0           1.0       40.0
# 1                 NaN           0.0       37.0
# 2                27.0           1.0       40.0
# 3                24.0           0.0       40.0
# 4                24.0           1.0       40.0
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Raw Data Analysis<a name="paragraph2"></a>
# Now that we have loaded the raw data into one place, let's take a look at initial findings.

# %% [markdown]
# ### EV Survey Data<a name="subparagraph1"></a>

# %%
ev_survey_output_raw.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4835 entries, 0 to 4834
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   response_id                   4833 non-null   float64
#  1   year_submitted_survey_2       4833 non-null   float64
#  2   months_owned                  4330 non-null   float64
#  3   year_make_model               4833 non-null   object
#  4   electric_range                4830 non-null   float64
#  5   ev_type                       4673 non-null   object
#  6   discontinuance                4833 non-null   object
#  7   surveyed_age                  4373 non-null   float64
#  8   surveyed_gender               4438 non-null   object
#  9   dist_1                        3811 non-null   float64
#  10  trips_greater_200             4833 non-null   float64
#  11  safety_satisfaction           4146 non-null   float64
#  12  comfort_satisfaction          4146 non-null   float64
#  13  refuel_recharge_satisfaction  4146 non-null   float64
#  14  performance_satisfaction      4146 non-null   float64
#  15  env_impact_satisfaction       4146 non-null   float64
#  16  purch_price_satisfaction      4146 non-null   float64
#  17  reliability_satisfaction      4146 non-null   float64
#  18  range_satisfaction            4146 non-null   float64
#  19  charge_access_satisfaction    4146 non-null   float64
#  20  adas_satisfaction             4146 non-null   float64
#  21  household_income              4088 non-null   object
#  22  home_charge_type              4833 non-null   object
#  23  work_charge_type              3174 non-null   object
#  24  highest_charge_used           3553 non-null   object
#  25  backup_vehicle_mpg            3789 non-null   float64
#  26  finance_type                  4833 non-null   float64
#  27  last_page                     4833 non-null   float64
# dtypes: float64(20), object(8)
# memory usage: 1.0+ MB

# %% [markdown]
# #### What percentage of null values is present in each column?

# %%
print(100*ev_survey_output_raw.isnull().mean().sort_values(ascending=True))


#plot the missing values for visual reference
a = 100*ev_survey_output_raw.isnull().mean().sort_values(ascending=True)
plt.plot(a)
plt.show()
# Out:
# response_id                      0.041365
# home_charge_type                 0.041365
# finance_type                     0.041365
# trips_greater_200                0.041365
# discontinuance                   0.041365
# last_page                        0.041365
# year_submitted_survey_2          0.041365
# year_make_model                  0.041365
# electric_range                   0.103413
# ev_type                          3.350569
# surveyed_gender                  8.210962
# surveyed_age                     9.555326
# months_owned                    10.444674
# adas_satisfaction               14.250259
# charge_access_satisfaction      14.250259
# range_satisfaction              14.250259
# reliability_satisfaction        14.250259
# purch_price_satisfaction        14.250259
# performance_satisfaction        14.250259
# comfort_satisfaction            14.250259
# safety_satisfaction             14.250259
# env_impact_satisfaction         14.250259
# refuel_recharge_satisfaction    14.250259
# household_income                15.449845
# dist_1                          21.178904
# backup_vehicle_mpg              21.633919
# highest_charge_used             26.514995
# work_charge_type                34.353671
# dtype: float64

# %% [markdown]
# Observations:
#
# * The satisfaction survey results share an almost identical number of missing entries
# * The peak missing value comes from the work_charge_type
# * The discontinuance data fortunately contains <1% missing entries.

# %%
fig_dims = (9, 6)
fig, ax = plt.subplots(figsize=fig_dims)
sns.heatmap(ev_survey_output_raw.isnull(), 
            yticklabels=False, 
            cbar=False, 
            cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## What is the ownership distribution of consumers for this study?
#
# __Definition__:
# * Continued means the user had an EV previously and bought another.
# * Original means the user is a first time EV owner.
# * Discontinued means that the user decided to get rid of their EV and go to a gasoline vehicle.

# %%
sns.set_theme
ax = sns.countplot(x = ev_survey_output_raw.discontinuance, data = ev_survey_output_raw)
plt.show()

# %% [markdown]
# ### Age distribution of the EV owners in the study

# %%
ax = sns.countplot(x = ev_survey_output_raw.surveyed_age, data = ev_survey_output_raw)
plt.show()

# %%
sns.pointplot(ev_survey_output_raw.electric_range, ev_survey_output_raw.months_owned)
# Out:
# C:\Users\mrpal\anaconda3\envs\ml_data_engineering\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='electric_range', ylabel='months_owned'>

# %% [markdown]
# ### Profile the raw data for the EV survey

# %%
#profile = ProfileReport(ev_survey_output_raw, title="Pandas Profiling Report")

# %%
#profile.to_widgets()

# %% [markdown]
# ### Profile the raw data for the EV vehicles

# %%
#profile = ProfileReport(ev_vehicle_data_raw, title="Pandas Profiling Report")

# %%
#profile.to_widgets()

# %%
ev_survey_output_raw.loc[ev_survey_output_raw.months_owned <= 12]
# Out:
#       response_id  year_submitted_survey_2  months_owned  \
# 521         540.0                   2019.0          12.0
# 524         543.0                   2019.0          12.0
# 545         564.0                   2019.0          11.0
# 567         586.0                   2019.0          11.0
# 657         679.0                   2019.0           3.0
# 791         820.0                   2019.0          11.0
# 864         896.0                   2019.0          11.0
# 958         992.0                   2019.0           5.0
# 1002       1039.0                   2019.0          11.0
# 1127       1169.0                   2019.0           9.0
# 1138       1180.0                   2019.0          12.0
# 1419       1476.0                   2019.0          11.0
# 1422       1479.0                   2019.0           6.0
# 1551       1612.0                   2019.0           7.0
# 1729       1793.0                   2019.0          10.0
# 1830       1899.0                   2019.0          -5.0
# 1906       1977.0                   2019.0          10.0
# 2017       2092.0                   2019.0          11.0
# 2018       2093.0                   2019.0          12.0
# 2028       2104.0                   2019.0          11.0
# 2073       2152.0                   2019.0           8.0
# 2127       2209.0                   2019.0          11.0
# 2150       2232.0                   2019.0          12.0
# 2160       2243.0                   2019.0          12.0
# 2269       2358.0                   2019.0          12.0
# 2478       2570.0                   2019.0           3.0
# 2643       2739.0                   2019.0          11.0
# 2689       2785.0                   2019.0           1.0
# 3100       3219.0                   2019.0          12.0
# 3132       3252.0                   2019.0          11.0
# 3135       3255.0                   2019.0           1.0
# 3146       3267.0                   2019.0           9.0
# 3225       3350.0                   2019.0         -31.0
# 3232       3358.0                   2019.0           9.0
# 3353       3485.0                   2019.0           9.0
# 3800       3942.0                   2019.0          12.0
# 3885       4027.0                   2019.0          12.0
# 4014       4159.0                   2019.0           0.0
# 4058       4205.0                   2019.0           8.0
# 4147       4300.0                   2019.0          11.0
# 4269       4425.0                   2019.0          12.0
# 4471       4642.0                   2019.0          12.0
# 4571       4746.0                   2019.0          12.0
# 4668       4849.0                   2019.0          10.0
#
#                                 year_make_model  electric_range ev_type  \
# 521   2014 Mercedes-Benz B-Class Electric Drive            87.0     BEV
# 524                            2017 Nissan Leaf            84.0     BEV
# 545           2018 Honda Clarity Plug-in Hybrid            48.0    PHEV
# 567                      2016 Volkswagen e-Golf            84.0     BEV
# 657                          2014 Tesla Model S           271.0     BEV
# 791                              2017 Fiat 500e            87.0     BEV
# 864               2018 Tesla Model 3 Long Range           310.0     BEV
# 958                          2016 Tesla Model X           270.0     BEV
# 1002                    2017 Toyota Prius Prime            25.0    PHEV
# 1127              2017 Tesla Model 3 Long Range           310.0     BEV
# 1138                     2017 Chevrolet Bolt EV           238.0     BEV
# 1419                   2012 Ford Focus Electric            76.0     BEV
# 1422                           2012 Nissan Leaf            84.0     BEV
# 1551                     2016 Volkswagen e-Golf            84.0     BEV
# 1729                      2017 Honda Clarity EV            89.0     BEV
# 1830                        2013 Chevrolet Volt            53.0    PHEV
# 1906                         2013 Tesla Model S           271.0     BEV
# 2017          2018 Honda Clarity Plug-in Hybrid            48.0    PHEV
# 2018                        2018 Chevrolet Volt            53.0    PHEV
# 2028          2019 Honda Clarity Plug in Hybrid             NaN     NaN
# 2073                     2014 Ford C-Max Energi            20.0    PHEV
# 2127         2018 Hyundai Sonata Plug-in Hybrid            28.0    PHEV
# 2150                         2016 Tesla Model S           271.0     BEV
# 2160                           2015 Kia Soul EV           111.0     BEV
# 2269                     2017 Volkswagen e-Golf            84.0     BEV
# 2478                           2016 Nissan Leaf            84.0     BEV
# 2643                     2016 Volkswagen e-Golf            84.0     BEV
# 2689                  2014 Toyota Prius Plug-in            11.0    PHEV
# 3100                        2016 Chevrolet Volt            53.0    PHEV
# 3132                     2017 Volkswagen e-Golf            84.0     BEV
# 3135                           2015 Nissan Leaf            84.0     BEV
# 3146                     2016 Volkswagen e-Golf            84.0     BEV
# 3225                    2014 Chevrolet Spark EV            82.0     BEV
# 3232                     2014 Ford C-Max Energi            20.0    PHEV
# 3353                           2012 Nissan Leaf            84.0     BEV
# 3800                         2015 Tesla Model S           271.0     BEV
# 3885                                2015 BMW i3            81.0    PHEV
# 4014                     2014 Ford C-Max Energi            20.0    PHEV
# 4058         2017 Hyundai Sonata Plug-in Hybrid            28.0    PHEV
# 4147                                2014 BMW i3            81.0    PHEV
# 4269                           2016 Kia Soul EV           111.0     BEV
# 4471                     2018 Chevrolet Bolt EV           238.0     BEV
# 4571                         2016 Tesla Model X           270.0     BEV
# 4668      2017 BMW i3 BEV (94 Amp-hour battery)           114.0     BEV
#
#      discontinuance  surveyed_age surveyed_gender   dist_1  ...  \
# 521       Continued          45.0            Male      NaN  ...
# 524       Continued          65.0          Female    48.94  ...
# 545        Original          25.0            Male    10.71  ...
# 567       Continued          45.0            Male    14.76  ...
# 657       Continued          75.0            Male  1686.40  ...
# 791        Original          35.0            Male    19.83  ...
# 864       Continued          65.0            Male    13.75  ...
# 958       Continued          55.0            Male    19.12  ...
# 1002   Discontinued          55.0            Male     8.20  ...
# 1127      Continued          80.0            Male      NaN  ...
# 1138   Discontinued          35.0          Female    17.27  ...
# 1419       Original           NaN             NaN      NaN  ...
# 1422      Continued          45.0            Male   199.28  ...
# 1551      Continued          45.0          Female     5.67  ...
# 1729       Original           NaN             NaN      NaN  ...
# 1830      Continued          75.0            Male      NaN  ...
# 1906       Original           NaN             NaN      NaN  ...
# 2017       Original          35.0          Female    21.07  ...
# 2018       Original          35.0          Female      NaN  ...
# 2028       Original          80.0            Male    11.10  ...
# 2073   Discontinued          65.0          Female     5.57  ...
# 2127       Original          75.0          Female     7.62  ...
# 2150      Continued          65.0            Male      NaN  ...
# 2160   Discontinued          75.0          Female      NaN  ...
# 2269      Continued           NaN            Male    22.10  ...
# 2478      Continued          45.0            Male     3.77  ...
# 2643      Continued          55.0          Female     8.06  ...
# 2689   Discontinued          45.0            Male    11.95  ...
# 3100      Continued          65.0            Male    30.87  ...
# 3132       Original          55.0            Male    32.98  ...
# 3135      Continued          55.0            Male    13.58  ...
# 3146      Continued          45.0            Male    40.19  ...
# 3225      Continued          75.0            Male      NaN  ...
# 3232   Discontinued          45.0            Male    66.94  ...
# 3353      Continued          65.0          Female      NaN  ...
# 3800      Continued          55.0          Female   170.57  ...
# 3885      Continued          75.0            Male     3.72  ...
# 4014   Discontinued          65.0            Male      NaN  ...
# 4058      Continued          45.0            Male     1.81  ...
# 4147      Continued          65.0            Male     2.65  ...
# 4269      Continued          45.0            Male    17.28  ...
# 4471      Continued          55.0            Male    25.68  ...
# 4571      Continued          35.0            Male    22.56  ...
# 4668      Continued          45.0            Male     6.90  ...
#
#       range_satisfaction  charge_access_satisfaction  adas_satisfaction  \
# 521                  2.0                         3.0                3.0
# 524                  1.0                         1.0                4.0
# 545                  4.0                         4.0                4.0
# 567                  1.0                         1.0                1.0
# 657                  4.0                         5.0                5.0
# 791                  3.0                         5.0                4.0
# 864                  5.0                         4.0                4.0
# 958                  2.0                         4.0                4.0
# 1002                 4.0                         5.0                5.0
# 1127                 5.0                         5.0                5.0
# 1138                 4.0                         4.0                5.0
# 1419                 NaN                         NaN                NaN
# 1422                 1.0                         1.0                4.0
# 1551                 1.0                         3.0                3.0
# 1729                 NaN                         NaN                NaN
# 1830                 4.0                         5.0                5.0
# 1906                 NaN                         NaN                NaN
# 2017                 4.0                         4.0                5.0
# 2018                 4.0                         2.0                5.0
# 2028                 5.0                         5.0                4.0
# 2073                 3.0                         3.0                1.0
# 2127                 1.0                         5.0                5.0
# 2150                 NaN                         NaN                NaN
# 2160                 4.0                         2.0                4.0
# 2269                 1.0                         4.0                2.0
# 2478                 2.0                         2.0                1.0
# 2643                 4.0                         5.0                3.0
# 2689                 1.0                         5.0                2.0
# 3100                 5.0                         5.0                5.0
# 3132                 2.0                         5.0                5.0
# 3135                 5.0                         5.0                5.0
# 3146                 4.0                         2.0                5.0
# 3225                 1.0                         5.0                5.0
# 3232                 4.0                         4.0                5.0
# 3353                 1.0                         1.0                1.0
# 3800                 1.0                         1.0                1.0
# 3885                 1.0                         1.0                3.0
# 4014                 NaN                         NaN                NaN
# 4058                 2.0                         2.0                5.0
# 4147                 1.0                         5.0                3.0
# 4269                 3.0                         3.0                2.0
# 4471                 4.0                         4.0                2.0
# 4571                 4.0                         5.0                5.0
# 4668                 2.0                         4.0                3.0
#
#             household_income  home_charge_type  work_charge_type  \
# 521         $500,000 or more           Level 1           Level 1
# 524   I prefer not to answer           Level 2           DC Fast
# 545       $50,000 to $99,999       No Charging           Level 2
# 567   I prefer not to answer           Level 2           Level 2
# 657         $500,000 or more           Level 2               NaN
# 791     $200,000 to $249,999           Level 1       No charging
# 864   I prefer not to answer           Level 2       No charging
# 958        Less than $50,000           Level 2       No charging
# 1002      $50,000 to $99,999           Level 1           Level 2
# 1127    $200,000 to $249,999           Level 2       No charging
# 1138    $150,000 to $199,999           Level 1       No charging
# 1419                     NaN           Level 1               NaN
# 1422  I prefer not to answer           Level 2               NaN
# 1551    $150,000 to $199,999           Level 2           Level 2
# 1729                     NaN           Level 2       No charging
# 1830    $300,000 to $349,999           Level 2               NaN
# 1906                     NaN           Level 2               NaN
# 2017    $150,000 to $199,999           Level 1       No charging
# 2018    $200,000 to $249,999           Level 2       No charging
# 2028      $50,000 to $99,999       No Charging               NaN
# 2073      $50,000 to $99,999           Level 1       No charging
# 2127      $50,000 to $99,999           Level 1       No charging
# 2150                     NaN           Level 2       No charging
# 2160      $50,000 to $99,999       No Charging           Level 1
# 2269  I prefer not to answer           Level 1           Level 2
# 2478                     NaN           Level 2       No charging
# 2643    $350,000 to $399,999           Level 1       No charging
# 2689    $100,000 to $149,999           Level 1               NaN
# 3100    $150,000 to $199,999           Level 1           Level 2
# 3132    $150,000 to $199,999       No Charging           Level 1
# 3135    $350,000 to $399,999           Level 2       No charging
# 3146       Less than $50,000           Level 1       No charging
# 3225  I prefer not to answer           Level 2               NaN
# 3232    $200,000 to $249,999           Level 1           Level 2
# 3353    $150,000 to $199,999       No Charging               NaN
# 3800    $200,000 to $249,999       No Charging           Level 2
# 3885        $500,000 or more           Level 2       No charging
# 4014                     NaN           Level 1               NaN
# 4058    $100,000 to $149,999           Level 1       No charging
# 4147    $200,000 to $249,999           Level 2               NaN
# 4269        $500,000 or more           Level 2           Level 2
# 4471    $150,000 to $199,999           Level 2           Level 2
# 4571    $200,000 to $249,999           Level 1       No charging
# 4668    $150,000 to $199,999           Level 1           Level 1
#
#       highest_charge_used  backup_vehicle_mpg  finance_type  last_page
# 521                   NaN                24.0           1.0       40.0
# 524           No charging                31.0           1.0       40.0
# 545           No charging                28.0           0.0       40.0
# 567           No charging                24.0           1.0       40.0
# 657               DC Fast                50.0           0.0       40.0
# 791           No charging                 NaN           1.0       40.0
# 864               Level 2               119.0           0.0       40.0
# 958               DC Fast                 NaN           0.0       40.0
# 1002          No charging                31.0           0.0       40.0
# 1127          No charging                98.0           0.0       40.0
# 1138          No charging                26.0           1.0       40.0
# 1419              Level 2                15.0           1.0        8.0
# 1422                  NaN                24.0           1.0       40.0
# 1551          No charging                39.0           1.0       40.0
# 1729          No charging                24.0           1.0        5.0
# 1830                  NaN                16.0           1.0       40.0
# 1906                  NaN                 NaN           1.0        6.0
# 2017          No charging                24.0           0.0       40.0
# 2018          No charging                36.0           0.0       40.0
# 2028                  NaN                 NaN           0.0       40.0
# 2073          No charging                29.0           1.0       40.0
# 2127          No charging                 NaN           0.0       40.0
# 2150          No charging                24.0           0.0       16.0
# 2160              Level 1                30.0           0.0       40.0
# 2269          No charging                24.0           1.0       40.0
# 2478              Level 2                24.0           1.0       29.0
# 2643          No charging                24.0           1.0       40.0
# 2689                  NaN                23.0           0.0       40.0
# 3100          No charging                16.0           1.0       40.0
# 3132          No charging                23.0           1.0       40.0
# 3135          No charging                95.0           1.0       40.0
# 3146              Level 2                24.0           1.0       40.0
# 3225                  NaN                47.0           1.0       40.0
# 3232          No charging                23.0           0.0       40.0
# 3353              DC Fast                41.0           1.0       40.0
# 3800          No charging                17.0           0.0       40.0
# 3885          No charging                89.0           1.0       40.0
# 4014                  NaN                15.0           1.0       16.0
# 4058          No charging                 NaN           1.0       40.0
# 4147              Level 2                26.0           0.0       40.0
# 4269              Level 2                18.0           1.0       40.0
# 4471    Level 2 & DC Fast                 NaN           0.0       40.0
# 4571              DC Fast                 NaN           1.0       40.0
# 4668          No charging                25.0           1.0       40.0
#
# [44 rows x 28 columns]

# %%
ev_survey_output_raw.index[ev_survey_output_raw['months_owned'] == True].tolist()
# Out:
# [2689, 3135]

# %% [markdown]
# ### For the purposes of generating a predictive model, the users who are original owners need to be dropped as there is not a way to predict their next behavior.

# %%
#Retain the data for the users who are known to have either discontinued EV ownership or are continued owners.

ev_ownership_sans_original_owners = ev_survey_output_raw.loc[(ev_survey_output_raw.discontinuance == 'Continued') |
                                                             (ev_survey_output_raw.discontinuance == 'Discontinued')]

# %%
text = f"The raw dataset included {len(ev_survey_output_raw)} entries, after filtering the original owners there are now {len(ev_ownership_sans_original_owners)} entries."
print(text)
# Out:
# The raw dataset included 4835 entries, after filtering the original owners there are now 1947 entries.

# %%
ev_ownership_sans_original_owners.head()
#ev_ownership_sans_original_owners.info()
# Out:
#     response_id  year_submitted_survey_2  months_owned  \
# 0           1.0                   2019.0          24.0
# 6           7.0                   2019.0          14.0
# 9          11.0                   2019.0          48.0
# 10         12.0                   2019.0          30.0
# 11         13.0                   2019.0          31.0
#
#            year_make_model  electric_range ev_type discontinuance  \
# 0              2016 BMW i3            81.0    PHEV      Continued
# 6           2016 Fiat 500e            87.0     BEV      Continued
# 9         2015 Nissan Leaf            84.0     BEV   Discontinued
# 10             2015 BMW i3            81.0    PHEV      Continued
# 11  2016 Volkswagen e-Golf            84.0     BEV      Continued
#
#     surveyed_age surveyed_gender  dist_1  ...  range_satisfaction  \
# 0           25.0            Male   13.92  ...                 5.0
# 6           35.0            Male    8.54  ...                 1.0
# 9           55.0            Male     NaN  ...                 1.0
# 10          55.0            Male    9.43  ...                 2.0
# 11          35.0            Male   16.32  ...                 2.0
#
#     charge_access_satisfaction  adas_satisfaction        household_income  \
# 0                          5.0                5.0    $150,000 to $199,999
# 6                          3.0                3.0      $50,000 to $99,999
# 9                          2.0                1.0  I prefer not to answer
# 10                         3.0                3.0    $100,000 to $149,999
# 11                         4.0                2.0    $150,000 to $199,999
#
#     home_charge_type  work_charge_type  highest_charge_used  \
# 0        No Charging       No charging              Level 2
# 6            Level 1       No charging              Level 2
# 9            Level 1       No charging          No charging
# 10           Level 2           Level 1          No charging
# 11           Level 1           Level 1    Level 1 & Level 2
#
#     backup_vehicle_mpg  finance_type  last_page
# 0                 25.0           1.0       40.0
# 6                 82.0           1.0       40.0
# 9                 24.0           1.0       40.0
# 10                34.0           1.0       40.0
# 11                 NaN           1.0       40.0
#
# [5 rows x 28 columns]

# %%
#profile = ProfileReport(ev_ownership_sans_original_owners, title="Pandas Profiling Report")

# %%
#profile.to_widgets()

# %% [markdown]
# ## Modify column headers and data so that it can be merged

# %% [markdown]
# ### Split the attributes for the Year Make and Model of each vehicle in the survey into separate columns

# %%
models_makes = ev_ownership_sans_original_owners["year_make_model"].str.split(" ", n = 1, expand = True)

year         = models_makes[0].str.split(" ", n = 1, expand = True)[0]
make         = models_makes[1].str.split(" ", n = 1, expand = True)[0]
model        = models_makes[1].str.split(" ", n = 1, expand = True)[0:][1]

temp_my_make = pd.DataFrame(columns =['year','make', 'model'] )
temp_my_make['year']  = year
temp_my_make['make']  = make
temp_my_make['model'] = model
temp_my_make.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\ml_data_engineering\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year_make_model'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-62a886a72ee7> in <module>
# ----> 1 models_makes = ev_ownership_sans_original_owners["year_make_model"].str.split(" ", n = 1, expand = True)
#       2
#       3 year         = models_makes[0].str.split(" ", n = 1, expand = True)[0]
#       4 make         = models_makes[1].str.split(" ", n = 1, expand = True)[0]
#       5 model        = models_makes[1].str.split(" ", n = 1, expand = True)[0:][1]
#
# ~\anaconda3\envs\ml_data_engineering\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\envs\ml_data_engineering\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'year_make_model'

# %%
#What are the unique vehicle models in the vehicle data list?
ev_vehicle_data_raw.Model.unique()
# Out:
# array(['e-tron 55 quattro', 'e-tron 50 quattro', 'e-tron S quattro',
#        'e-tron Sportback 50 quattro', 'e-tron Sportback 55 quattro',
#        'e-tron Sportback S quattro', 'i3', 'i3s', 'iX3', 'ë-C4',
#        'DS3 Crossback e-tense', 'e', 'e Advance', 'Ioniq electric',
#        'Kona electric 39.2kWh', 'Kona electric 64kWh', 'I-Pace',
#        'e-Niro 39.2kWh', 'e-Niro 64kWh', 'e-Soul 39.2kWh', 'e-Soul 64kWh',
#        'MX-30', 'EQC', 'Cooper SE', 'Leaf', 'Leaf e+', 'Corsa-e',
#        'Mokka-e', 'e-208', 'e-2008', 'Taycan 4S (Performance)',
#        'Taycan 4S (Performance Plus)', 'Taycan Turbo', 'Taycan Turbo S',
#        'Zoe R110', 'Zoe R135', 'Citigo-e iV', 'fortwo EQ', 'forfour EQ',
#        'Model 3 Standard Range Plus', 'Model 3 Long Range',
#        'Model 3 Performance', 'Model S Long Range Plus',
#        'Model S Performance', 'Model X Long Range Plus',
#        'Model X Performance', 'e-up!', 'ID.3 Pro Performance',
#        'ID.3 Pro S', 'ID.4 1st', 'ë-Spacetourer (M)', 'EQV (long)',
#        'e-NV200 evalia'], dtype=object)

# %%
#What are the unique vehicle models in the survey?
temp_my_make.model.unique()
# Out:
# array(['i3', '500e', 'Leaf', 'e-Golf', 'Prius Plug-in', 'C-Max Energi',
#        'Volt', 'Model S', 'Fusion Energi', 'Soul EV', 'Model X', 'i-MiEV',
#        'Spark EV', 'Sonata Plug-in Hybrid', 'eGolf', 'Bolt EV', 'Mirai',
#        'A3 Sportback e-tron', 'Fit EV', 'RAV4 EV', ' Prius Plug-In',
#        'Tucson', 'Model X 75D', 'Focus Electric',
#        'B-Class Electric Drive', 'i3 REX  (94 Amp-hour battery)', 'B250e',
#        'Model 3 Long Range', 'ELR', 'C-MAX Energi Plug-in Hybrid',
#        'Accord Plug-in Hybrid', 'Prius Prime', 'fortwo', 'Ioniq Electric',
#        'EV Ranger', 'Tuscan', 'E-Gulf', 'Model S (75 kW-hr battery pack)',
#        'DS 11.4 KWH battery', 'Model S (60 kW-hr battery pack)', 'ecmax',
#        'Prius', 'leaf', 'LEAF', 'i8', 'I3 Rex', 'Tuscon', 'Tuscon FCV',
#        'S-Class', 'fortwo electric drive convertible',
#        'C-MAX Energi Plug-In Hybrid', '500E', '85 S', 'Tucson fuel cell',
#        'tuscon', 'i3 BEV (94 Amp-hour battery)', 'Clarity Fuel Cell',
#        ' Volt', ' Chevrolet Volt', ' Model X'], dtype=object)

# %%
ev_ownership_sans_original_owners['model_year'] = temp_my_make.year
ev_ownership_sans_original_owners['Make']       = temp_my_make.make
ev_ownership_sans_original_owners['Model']      = temp_my_make.model
# Out:
# <ipython-input-25-23f1cef634e8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ev_ownership_sans_original_owners['model_year'] = temp_my_make.year
# <ipython-input-25-23f1cef634e8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ev_ownership_sans_original_owners['Make']       = temp_my_make.make
# <ipython-input-25-23f1cef634e8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ev_ownership_sans_original_owners['Model']      = temp_my_make.model

# %%
ev_ownership_sans_original_owners.head()
# Out:
#     response_id  year_submitted_survey_2  months_owned  \
# 0           1.0                   2019.0          24.0
# 6           7.0                   2019.0          14.0
# 9          11.0                   2019.0          48.0
# 10         12.0                   2019.0          30.0
# 11         13.0                   2019.0          31.0
#
#            year_make_model  electric_range ev_type discontinuance  \
# 0              2016 BMW i3            81.0    PHEV      Continued
# 6           2016 Fiat 500e            87.0     BEV      Continued
# 9         2015 Nissan Leaf            84.0     BEV   Discontinued
# 10             2015 BMW i3            81.0    PHEV      Continued
# 11  2016 Volkswagen e-Golf            84.0     BEV      Continued
#
#     surveyed_age surveyed_gender  dist_1  ...        household_income  \
# 0           25.0            Male   13.92  ...    $150,000 to $199,999
# 6           35.0            Male    8.54  ...      $50,000 to $99,999
# 9           55.0            Male     NaN  ...  I prefer not to answer
# 10          55.0            Male    9.43  ...    $100,000 to $149,999
# 11          35.0            Male   16.32  ...    $150,000 to $199,999
#
#     home_charge_type  work_charge_type  highest_charge_used  \
# 0        No Charging       No charging              Level 2
# 6            Level 1       No charging              Level 2
# 9            Level 1       No charging          No charging
# 10           Level 2           Level 1          No charging
# 11           Level 1           Level 1    Level 1 & Level 2
#
#     backup_vehicle_mpg  finance_type  last_page  model_year        Make  \
# 0                 25.0           1.0       40.0        2016         BMW
# 6                 82.0           1.0       40.0        2016        Fiat
# 9                 24.0           1.0       40.0        2015      Nissan
# 10                34.0           1.0       40.0        2015         BMW
# 11                 NaN           1.0       40.0        2016  Volkswagen
#
#      Model
# 0       i3
# 6     500e
# 9     Leaf
# 10      i3
# 11  e-Golf
#
# [5 rows x 31 columns]

# %%
column_list = ev_ownership_sans_original_owners.columns.to_list()

# %%
#Extract the current column list
column_list
# Out:
# ['response_id',
#  'year_submitted_survey_2',
#  'months_owned',
#  'year_make_model',
#  'electric_range',
#  'ev_type',
#  'discontinuance',
#  'surveyed_age',
#  'surveyed_gender',
#  'dist_1',
#  'trips_greater_200',
#  'safety_satisfaction',
#  'comfort_satisfaction',
#  'refuel_recharge_satisfaction',
#  'performance_satisfaction',
#  'env_impact_satisfaction',
#  'purch_price_satisfaction',
#  'reliability_satisfaction',
#  'range_satisfaction',
#  'charge_access_satisfaction',
#  'adas_satisfaction',
#  'household_income',
#  'home_charge_type',
#  'work_charge_type',
#  'highest_charge_used',
#  'backup_vehicle_mpg',
#  'finance_type',
#  'last_page',
#  'model_year',
#  'Make',
#  'Model']

# %%
# Reorganize them to the preferred order
column_list = ['response_id',
 'year_submitted_survey_2',
 'months_owned',
 'model_year',
 'Make',
 'Model',           
 'year_make_model',
 'electric_range',
 'ev_type',
 'discontinuance',
 'surveyed_age',
 'surveyed_gender',
 'dist_1',
 'trips_greater_200',
 'safety_satisfaction',
 'comfort_satisfaction',
 'refuel_recharge_satisfaction',
 'performance_satisfaction',
 'env_impact_satisfaction',
 'purch_price_satisfaction',
 'reliability_satisfaction',
 'range_satisfaction',
 'charge_access_satisfaction',
 'adas_satisfaction',
 'household_income',
 'home_charge_type',
 'work_charge_type',
 'highest_charge_used',
 'backup_vehicle_mpg',
 'finance_type',
 'last_page']

# %%
ev_ownership_sans_original_owners = ev_ownership_sans_original_owners.reindex(columns = column_list)
ev_ownership_sans_original_owners.drop(columns = ['year_make_model'], inplace=True)

# %%
ev_ownership_sans_original_owners.head()
# Out:
#     response_id  year_submitted_survey_2  months_owned model_year        Make  \
# 0           1.0                   2019.0          24.0       2016         BMW
# 6           7.0                   2019.0          14.0       2016        Fiat
# 9          11.0                   2019.0          48.0       2015      Nissan
# 10         12.0                   2019.0          30.0       2015         BMW
# 11         13.0                   2019.0          31.0       2016  Volkswagen
#
#      Model  electric_range ev_type discontinuance  surveyed_age  ...  \
# 0       i3            81.0    PHEV      Continued          25.0  ...
# 6     500e            87.0     BEV      Continued          35.0  ...
# 9     Leaf            84.0     BEV   Discontinued          55.0  ...
# 10      i3            81.0    PHEV      Continued          55.0  ...
# 11  e-Golf            84.0     BEV      Continued          35.0  ...
#
#    range_satisfaction  charge_access_satisfaction  adas_satisfaction  \
# 0                 5.0                         5.0                5.0
# 6                 1.0                         3.0                3.0
# 9                 1.0                         2.0                1.0
# 10                2.0                         3.0                3.0
# 11                2.0                         4.0                2.0
#
#           household_income  home_charge_type  work_charge_type  \
# 0     $150,000 to $199,999       No Charging       No charging
# 6       $50,000 to $99,999           Level 1       No charging
# 9   I prefer not to answer           Level 1       No charging
# 10    $100,000 to $149,999           Level 2           Level 1
# 11    $150,000 to $199,999           Level 1           Level 1
#
#     highest_charge_used  backup_vehicle_mpg  finance_type  last_page
# 0               Level 2                25.0           1.0       40.0
# 6               Level 2                82.0           1.0       40.0
# 9           No charging                24.0           1.0       40.0
# 10          No charging                34.0           1.0       40.0
# 11    Level 1 & Level 2                 NaN           1.0       40.0
#
# [5 rows x 30 columns]

# %%
ev_vehicle_data_raw.head()
# Out:
#                       Car full name  Make                        Model  \
# 0            Audi e-tron 55 quattro  Audi            e-tron 55 quattro
# 1            Audi e-tron 50 quattro  Audi            e-tron 50 quattro
# 2             Audi e-tron S quattro  Audi             e-tron S quattro
# 3  Audi e-tron Sportback 50 quattro  Audi  e-tron Sportback 50 quattro
# 4  Audi e-tron Sportback 55 quattro  Audi  e-tron Sportback 55 quattro
#
#    Minimal price (gross) [PLN]  Engine power [KM]  Maximum torque [Nm]  \
# 0                       345700                360                  664
# 1                       308400                313                  540
# 2                       414900                503                  973
# 3                       319700                313                  540
# 4                       357000                360                  664
#
#         Type of brakes Drive type  Battery capacity [kWh]  Range (WLTP) [km]  \
# 0  disc (front + rear)        4WD                    95.0                438
# 1  disc (front + rear)        4WD                    71.0                340
# 2  disc (front + rear)        4WD                    95.0                364
# 3  disc (front + rear)        4WD                    71.0                346
# 4  disc (front + rear)        4WD                    95.0                447
#
#    ...  Permissable gross weight [kg]  Maximum load capacity [kg]  \
# 0  ...                         3130.0                       640.0
# 1  ...                         3040.0                       670.0
# 2  ...                         3130.0                       565.0
# 3  ...                         3040.0                       640.0
# 4  ...                         3130.0                       670.0
#
#    Number of seats  Number of doors  Tire size [in]  Maximum speed [kph]  \
# 0                5                5              19                  200
# 1                5                5              19                  190
# 2                5                5              20                  210
# 3                5                5              19                  190
# 4                5                5              19                  200
#
#    Boot capacity (VDA) [l]  Acceleration 0-100 kph [s]  \
# 0                    660.0                         5.7
# 1                    660.0                         6.8
# 2                    660.0                         4.5
# 3                    615.0                         6.8
# 4                    615.0                         5.7
#
#    Maximum DC charging power [kW]  mean - Energy consumption [kWh/100 km]
# 0                             150                                   24.45
# 1                             150                                   23.80
# 2                             150                                   27.55
# 3                             150                                   23.30
# 4                             150                                   23.85
#
# [5 rows x 25 columns]

# %% [markdown]
# #### Join the two dataframes together, add information from the EV vehicles list to the entries in the survey data

# %%
merged_ev_data = ev_ownership_sans_original_owners.merge(ev_vehicle_data_raw, on=['Make','Model'], how='left')

# %%
merged_ev_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1947 entries, 0 to 1946
# Data columns (total 53 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   response_id                             1947 non-null   float64
#  1   year_submitted_survey_2                 1947 non-null   float64
#  2   months_owned                            1851 non-null   float64
#  3   model_year                              1947 non-null   object
#  4   Make                                    1947 non-null   object
#  5   Model                                   1947 non-null   object
#  6   electric_range                          1946 non-null   float64
#  7   ev_type                                 1908 non-null   object
#  8   discontinuance                          1947 non-null   object
#  9   surveyed_age                            1872 non-null   float64
#  10  surveyed_gender                         1899 non-null   object
#  11  dist_1                                  1615 non-null   float64
#  12  trips_greater_200                       1947 non-null   float64
#  13  safety_satisfaction                     1753 non-null   float64
#  14  comfort_satisfaction                    1753 non-null   float64
#  15  refuel_recharge_satisfaction            1753 non-null   float64
#  16  performance_satisfaction                1753 non-null   float64
#  17  env_impact_satisfaction                 1753 non-null   float64
#  18  purch_price_satisfaction                1753 non-null   float64
#  19  reliability_satisfaction                1753 non-null   float64
#  20  range_satisfaction                      1753 non-null   float64
#  21  charge_access_satisfaction              1753 non-null   float64
#  22  adas_satisfaction                       1753 non-null   float64
#  23  household_income                        1724 non-null   object
#  24  home_charge_type                        1947 non-null   object
#  25  work_charge_type                        1121 non-null   object
#  26  highest_charge_used                     1370 non-null   object
#  27  backup_vehicle_mpg                      1587 non-null   float64
#  28  finance_type                            1947 non-null   float64
#  29  last_page                               1947 non-null   float64
#  30  Car full name                           562 non-null    object
#  31  Minimal price (gross) [PLN]             562 non-null    float64
#  32  Engine power [KM]                       562 non-null    float64
#  33  Maximum torque [Nm]                     562 non-null    float64
#  34  Type of brakes                          562 non-null    object
#  35  Drive type                              562 non-null    object
#  36  Battery capacity [kWh]                  562 non-null    float64
#  37  Range (WLTP) [km]                       562 non-null    float64
#  38  Wheelbase [cm]                          562 non-null    float64
#  39  Length [cm]                             562 non-null    float64
#  40  Width [cm]                              562 non-null    float64
#  41  Height [cm]                             562 non-null    float64
#  42  Minimal empty weight [kg]               562 non-null    float64
#  43  Permissable gross weight [kg]           560 non-null    float64
#  44  Maximum load capacity [kg]              560 non-null    float64
#  45  Number of seats                         562 non-null    float64
#  46  Number of doors                         562 non-null    float64
#  47  Tire size [in]                          562 non-null    float64
#  48  Maximum speed [kph]                     562 non-null    float64
#  49  Boot capacity (VDA) [l]                 562 non-null    float64
#  50  Acceleration 0-100 kph [s]              562 non-null    float64
#  51  Maximum DC charging power [kW]          562 non-null    float64
#  52  mean - Energy consumption [kWh/100 km]  560 non-null    float64
# dtypes: float64(40), object(13)
# memory usage: 821.4+ KB

# %%
merged_ev_data.head(30)
# Out:
#     response_id  year_submitted_survey_2  months_owned model_year        Make  \
# 0           1.0                   2019.0          24.0       2016         BMW
# 1           7.0                   2019.0          14.0       2016        Fiat
# 2          11.0                   2019.0          48.0       2015      Nissan
# 3          12.0                   2019.0          30.0       2015         BMW
# 4          13.0                   2019.0          31.0       2016  Volkswagen
# 5          23.0                   2019.0          34.0       2015      Nissan
# 6          27.0                   2019.0          54.0       2013      Toyota
# 7          30.0                   2019.0           NaN       2011      Nissan
# 8          31.0                   2019.0          84.0       2012      Toyota
# 9          32.0                   2019.0          35.0       2015        Ford
# 10         34.0                   2019.0          33.0       2016   Chevrolet
# 11         42.0                   2019.0          49.0       2013      Nissan
# 12         43.0                   2019.0          58.0       2014      Nissan
# 13         44.0                   2019.0          71.0       2013   Chevrolet
# 14         48.0                   2019.0          18.0       2014       Tesla
# 15         55.0                   2019.0          43.0       2015       Tesla
# 16         57.0                   2019.0          30.0       2016  Volkswagen
# 17         61.0                   2019.0          36.0       2016   Chevrolet
# 18         62.0                   2019.0          34.0       2013       Tesla
# 19         67.0                   2019.0          36.0       2015      Nissan
# 20         68.0                   2019.0          36.0       2016   Chevrolet
# 21         71.0                   2019.0          35.0       2015        Ford
# 22         77.0                   2019.0          40.0       2016   Chevrolet
# 23         80.0                   2019.0          53.0       2015        Ford
# 24         87.0                   2019.0          51.0       2015         Kia
# 25         88.0                   2019.0          14.0       2014         BMW
# 26         92.0                   2019.0          36.0       2016        FIAT
# 27         95.0                   2019.0          35.0       2016       Tesla
# 28         99.0                   2019.0          48.0       2015      Nissan
# 29        100.0                   2019.0          33.0       2012      Nissan
#
#             Model  electric_range ev_type discontinuance  surveyed_age  ...  \
# 0              i3            81.0    PHEV      Continued          25.0  ...
# 1            500e            87.0     BEV      Continued          35.0  ...
# 2            Leaf            84.0     BEV   Discontinued          55.0  ...
# 3              i3            81.0    PHEV      Continued          55.0  ...
# 4          e-Golf            84.0     BEV      Continued          35.0  ...
# 5            Leaf            84.0     BEV      Continued          75.0  ...
# 6   Prius Plug-in            11.0    PHEV      Continued          65.0  ...
# 7            Leaf            84.0     BEV      Continued          65.0  ...
# 8   Prius Plug-in            11.0    PHEV      Continued          45.0  ...
# 9    C-Max Energi            20.0    PHEV      Continued          45.0  ...
# 10           Volt            53.0    PHEV      Continued          45.0  ...
# 11           Leaf            84.0     BEV   Discontinued          65.0  ...
# 12           Leaf            84.0     BEV      Continued          45.0  ...
# 13           Volt            53.0    PHEV      Continued          75.0  ...
# 14        Model S           271.0     BEV      Continued          45.0  ...
# 15        Model S           271.0     BEV      Continued          75.0  ...
# 16         e-Golf            84.0     BEV      Continued          45.0  ...
# 17           Volt            53.0    PHEV      Continued          75.0  ...
# 18        Model S           271.0     BEV      Continued          55.0  ...
# 19           Leaf            84.0     BEV      Continued          55.0  ...
# 20           Volt            53.0    PHEV      Continued          65.0  ...
# 21   C-Max Energi            20.0    PHEV      Continued          55.0  ...
# 22           Volt            53.0    PHEV      Continued          25.0  ...
# 23  Fusion Energi            20.0    PHEV      Continued          75.0  ...
# 24        Soul EV           111.0     BEV      Continued          45.0  ...
# 25             i3            81.0     BEV   Discontinued          55.0  ...
# 26           500e            87.0     BEV   Discontinued          65.0  ...
# 27        Model S           271.0     BEV   Discontinued          75.0  ...
# 28           Leaf            84.0     BEV      Continued          65.0  ...
# 29           Leaf            84.0     BEV      Continued          65.0  ...
#
#    Permissable gross weight [kg]  Maximum load capacity [kg]  Number of seats  \
# 0                         1730.0                       440.0              4.0
# 1                            NaN                         NaN              NaN
# 2                         1995.0                       450.0              5.0
# 3                         1730.0                       440.0              4.0
# 4                            NaN                         NaN              NaN
# 5                         1995.0                       450.0              5.0
# 6                            NaN                         NaN              NaN
# 7                         1995.0                       450.0              5.0
# 8                            NaN                         NaN              NaN
# 9                            NaN                         NaN              NaN
# 10                           NaN                         NaN              NaN
# 11                        1995.0                       450.0              5.0
# 12                        1995.0                       450.0              5.0
# 13                           NaN                         NaN              NaN
# 14                           NaN                         NaN              NaN
# 15                           NaN                         NaN              NaN
# 16                           NaN                         NaN              NaN
# 17                           NaN                         NaN              NaN
# 18                           NaN                         NaN              NaN
# 19                        1995.0                       450.0              5.0
# 20                           NaN                         NaN              NaN
# 21                           NaN                         NaN              NaN
# 22                           NaN                         NaN              NaN
# 23                           NaN                         NaN              NaN
# 24                           NaN                         NaN              NaN
# 25                        1730.0                       440.0              4.0
# 26                           NaN                         NaN              NaN
# 27                           NaN                         NaN              NaN
# 28                        1995.0                       450.0              5.0
# 29                        1995.0                       450.0              5.0
#
#     Number of doors  Tire size [in]  Maximum speed [kph]  \
# 0               5.0            19.0                160.0
# 1               NaN             NaN                  NaN
# 2               5.0            16.0                144.0
# 3               5.0            19.0                160.0
# 4               NaN             NaN                  NaN
# 5               5.0            16.0                144.0
# 6               NaN             NaN                  NaN
# 7               5.0            16.0                144.0
# 8               NaN             NaN                  NaN
# 9               NaN             NaN                  NaN
# 10              NaN             NaN                  NaN
# 11              5.0            16.0                144.0
# 12              5.0            16.0                144.0
# 13              NaN             NaN                  NaN
# 14              NaN             NaN                  NaN
# 15              NaN             NaN                  NaN
# 16              NaN             NaN                  NaN
# 17              NaN             NaN                  NaN
# 18              NaN             NaN                  NaN
# 19              5.0            16.0                144.0
# 20              NaN             NaN                  NaN
# 21              NaN             NaN                  NaN
# 22              NaN             NaN                  NaN
# 23              NaN             NaN                  NaN
# 24              NaN             NaN                  NaN
# 25              5.0            19.0                160.0
# 26              NaN             NaN                  NaN
# 27              NaN             NaN                  NaN
# 28              5.0            16.0                144.0
# 29              5.0            16.0                144.0
#
#     Boot capacity (VDA) [l]  Acceleration 0-100 kph [s]  \
# 0                     260.0                         8.1
# 1                       NaN                         NaN
# 2                     435.0                         7.9
# 3                     260.0                         8.1
# 4                       NaN                         NaN
# 5                     435.0                         7.9
# 6                       NaN                         NaN
# 7                     435.0                         7.9
# 8                       NaN                         NaN
# 9                       NaN                         NaN
# 10                      NaN                         NaN
# 11                    435.0                         7.9
# 12                    435.0                         7.9
# 13                      NaN                         NaN
# 14                      NaN                         NaN
# 15                      NaN                         NaN
# 16                      NaN                         NaN
# 17                      NaN                         NaN
# 18                      NaN                         NaN
# 19                    435.0                         7.9
# 20                      NaN                         NaN
# 21                      NaN                         NaN
# 22                      NaN                         NaN
# 23                      NaN                         NaN
# 24                      NaN                         NaN
# 25                    260.0                         8.1
# 26                      NaN                         NaN
# 27                      NaN                         NaN
# 28                    435.0                         7.9
# 29                    435.0                         7.9
#
#     Maximum DC charging power [kW]  mean - Energy consumption [kWh/100 km]
# 0                             50.0                                    13.1
# 1                              NaN                                     NaN
# 2                             50.0                                    18.5
# 3                             50.0                                    13.1
# 4                              NaN                                     NaN
# 5                             50.0                                    18.5
# 6                              NaN                                     NaN
# 7                             50.0                                    18.5
# 8                              NaN                                     NaN
# 9                              NaN                                     NaN
# 10                             NaN                                     NaN
# 11                            50.0                                    18.5
# 12                            50.0                                    18.5
# 13                             NaN                                     NaN
# 14                             NaN                                     NaN
# 15                             NaN                                     NaN
# 16                             NaN                                     NaN
# 17                             NaN                                     NaN
# 18                             NaN                                     NaN
# 19                            50.0                                    18.5
# 20                             NaN                                     NaN
# 21                             NaN                                     NaN
# 22                             NaN                                     NaN
# 23                             NaN                                     NaN
# 24                             NaN                                     NaN
# 25                            50.0                                    13.1
# 26                             NaN                                     NaN
# 27                             NaN                                     NaN
# 28                            50.0                                    18.5
# 29                            50.0                                    18.5
#
# [30 rows x 53 columns]
